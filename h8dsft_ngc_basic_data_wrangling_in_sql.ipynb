# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()
project_id = "t-bounty-408704"

client = bigquery.Client(project=project_id)

# %%
# put your query here
query = """
SELECT * FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
"""
# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#           trip_id       subscriber_type bike_id bike_type  \
# 0         4098776  24 Hour Walk Up Pass      24   classic
# 1         4083633  24 Hour Walk Up Pass       3   classic
# 2         4073980  24 Hour Walk Up Pass      24   classic
# 3         4072213              Local365      88   classic
# 4         4052284  24 Hour Walk Up Pass     114   classic
# ...           ...                   ...     ...       ...
# 2112258  32008634    Student Membership   21709  electric
# 2112259  31874613    Student Membership   21903  electric
# 2112260  31876914               Local31   21688  electric
# 2112261  31743555    Student Membership   21703  electric
# 2112262  31971764    Student Membership   16456  electric
#
#                        start_time  start_station_id  \
# 0       2015-03-12 22:22:59+00:00              2546
# 1       2015-03-11 15:55:38+00:00              2712
# 2       2015-03-10 16:10:57+00:00              2545
# 3       2015-03-10 13:20:33+00:00              2823
# 4       2015-03-07 13:48:22+00:00              2712
# ...                           ...               ...
# 2112258 2023-11-26 15:28:53+00:00              7189
# 2112259 2023-11-11 10:15:01+00:00              7189
# 2112260 2023-11-11 13:16:18+00:00              7189
# 2112261 2023-11-01 12:10:52+00:00              7189
# 2112262 2023-11-19 18:35:39+00:00              7189
#
#                            start_station_name end_station_id  \
# 0                    ACC - West & 12th Street           2546
# 1                     Toomey Rd @ South Lamar           2712
# 2                     ACC - Rio Grande & 12th           2546
# 3        East 5th/Broadway @ Capital Metro HQ           2823
# 4                     Toomey Rd @ South Lamar           2712
# ...                                       ...            ...
# 2112258                       28th/Rio Grande           7189
# 2112259                       28th/Rio Grande           7189
# 2112260                       28th/Rio Grande           7189
# 2112261                       28th/Rio Grande           7189
# 2112262                       28th/Rio Grande           7189
#
#                              end_station_name  duration_minutes
# 0                    ACC - West & 12th Street                46
# 1                     Toomey Rd @ South Lamar                92
# 2                    ACC - West & 12th Street                24
# 3        East 5th/Broadway @ Capital Metro HQ                 8
# 4                     Toomey Rd @ South Lamar               143
# ...                                       ...               ...
# 2112258                       28th/Rio Grande                 2
# 2112259                       28th/Rio Grande                 5
# 2112260                       28th/Rio Grande                30
# 2112261                       28th/Rio Grande                 3
# 2112262                       28th/Rio Grande                15
#
# [2112263 rows x 10 columns]

# %% [markdown]
# # NO 1
#
# How many tables are in the austin_bikeshare dataset?

# %%
# put your query here
query = """
SELECT * FROM `bigquery-public-data.austin_bikeshare.__TABLES__`
"""
# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#              project_id        dataset_id            table_id  creation_time  \
# 0  bigquery-public-data  austin_bikeshare  bikeshare_stations  1495683814344
# 1  bigquery-public-data  austin_bikeshare     bikeshare_trips  1689612093433
#
#    last_modified_time  row_count  size_bytes  type
# 0       1703030433895        102       13163     1
# 1       1703031051063    2112263   245874263     1

# %% [markdown]
# # NO 2
# How many columns in the bikeshare_stations table have STRING data?

# %%
# put your query here
query = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'bikeshare_stations' AND data_type = 'STRING'
"""
# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#           table_catalog      table_schema       table_name  \
# 0  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 1  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 2  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 3  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 4  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 5  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 6  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 7  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 8  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 9  bigquery-public-data  austin_bikeshare  bikeshare_trips
#
#           column_name  ordinal_position is_nullable  data_type is_generated  \
# 0             trip_id                 1         YES     STRING        NEVER
# 1     subscriber_type                 2         YES     STRING        NEVER
# 2             bike_id                 3         YES     STRING        NEVER
# 3           bike_type                 4         YES     STRING        NEVER
# 4          start_time                 5         YES  TIMESTAMP        NEVER
# 5    start_station_id                 6         YES      INT64        NEVER
# 6  start_station_name                 7         YES     STRING        NEVER
# 7      end_station_id                 8         YES     STRING        NEVER
# 8    end_station_name                 9         YES     STRING        NEVER
# 9    duration_minutes                10         YES      INT64        NEVER
#
#   generation_expression is_stored is_hidden is_updatable is_system_defined  \
# 0                  None      None        NO         None                NO
# 1                  None      None        NO         None                NO
# 2                  None      None        NO         None                NO
# 3                  None      None        NO         None                NO
# 4                  None      None        NO         None                NO
# 5                  None      None        NO         None                NO
# 6                  None      None        NO         None                NO
# 7                  None      None        NO         None                NO
# 8                  None      None        NO         None                NO
# 9                  None      None        NO         None                NO
#
#   is_partitioning_column  clustering_ordinal_position collation_name  \
# 0                     NO                         <NA>           NULL
# 1                     NO                         <NA>           NULL
# 2                     NO                         <NA>           NULL
# 3                     NO                         <NA>           NULL
# 4                     NO                         <NA>           NULL
# 5                     NO                         <NA>           NULL
# 6                     NO                         <NA>           NULL
# 7                     NO                         <NA>           NULL
# 8                     NO                         <NA>           NULL
# 9                     NO                         <NA>           NULL
#
#   column_default rounding_mode
# 0           NULL          None
# 1           NULL          None
# 2           NULL          None
# 3           NULL          None
# 4           NULL          None
# 5           NULL          None
# 6           NULL          None
# 7           NULL          None
# 8           NULL          None
# 9           NULL          None

# %%
# put your query here
query = """
SELECT COUNT(*)
FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'bikeshare_stations' AND data_type = 'STRING'
"""
# Set up the query
query_job = client.query(query).to_dataframe()

query_job

# LINK : https://stackoverflow.com/questions/30361414/bigquery-get-the-total-number-of-columns-in-a-bigquery-table
# SELECT count(distinct column_name)
# FROM  `project_id`.name_of_dataset.INFORMATION_SCHEMA.COLUMNS
# WHERE table_name = "name_of_table"
# Out:
#    f0_
# 0    7

# %% [markdown]
# # NO 3
# Retrieve all trips where the bike_id is not null and the duration is greater than 1000 minutes.

# %%
# put your query here
query = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE table_name = 'bikeshare_trips'
"""
# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#           table_catalog      table_schema       table_name  \
# 0  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 1  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 2  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 3  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 4  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 5  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 6  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 7  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 8  bigquery-public-data  austin_bikeshare  bikeshare_trips
# 9  bigquery-public-data  austin_bikeshare  bikeshare_trips
#
#           column_name  ordinal_position is_nullable  data_type is_generated  \
# 0             trip_id                 1         YES     STRING        NEVER
# 1     subscriber_type                 2         YES     STRING        NEVER
# 2             bike_id                 3         YES     STRING        NEVER
# 3           bike_type                 4         YES     STRING        NEVER
# 4          start_time                 5         YES  TIMESTAMP        NEVER
# 5    start_station_id                 6         YES      INT64        NEVER
# 6  start_station_name                 7         YES     STRING        NEVER
# 7      end_station_id                 8         YES     STRING        NEVER
# 8    end_station_name                 9         YES     STRING        NEVER
# 9    duration_minutes                10         YES      INT64        NEVER
#
#   generation_expression is_stored is_hidden is_updatable is_system_defined  \
# 0                  None      None        NO         None                NO
# 1                  None      None        NO         None                NO
# 2                  None      None        NO         None                NO
# 3                  None      None        NO         None                NO
# 4                  None      None        NO         None                NO
# 5                  None      None        NO         None                NO
# 6                  None      None        NO         None                NO
# 7                  None      None        NO         None                NO
# 8                  None      None        NO         None                NO
# 9                  None      None        NO         None                NO
#
#   is_partitioning_column  clustering_ordinal_position collation_name  \
# 0                     NO                         <NA>           NULL
# 1                     NO                         <NA>           NULL
# 2                     NO                         <NA>           NULL
# 3                     NO                         <NA>           NULL
# 4                     NO                         <NA>           NULL
# 5                     NO                         <NA>           NULL
# 6                     NO                         <NA>           NULL
# 7                     NO                         <NA>           NULL
# 8                     NO                         <NA>           NULL
# 9                     NO                         <NA>           NULL
#
#   column_default rounding_mode
# 0           NULL          None
# 1           NULL          None
# 2           NULL          None
# 3           NULL          None
# 4           NULL          None
# 5           NULL          None
# 6           NULL          None
# 7           NULL          None
# 8           NULL          None
# 9           NULL          None

# %%
# put your query here
query = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE bike_id IS NOT NULL AND duration_minutes > 1000
"""
# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#        trip_id     subscriber_type bike_id bike_type  \
# 0     10342346             Walk Up     911   classic
# 1     10871188             Walk Up     193   classic
# 2     10871199             Walk Up     668   classic
# 3     11317281             Walk Up     479   classic
# 4     21605993            Local365    3212   classic
# ...        ...                 ...     ...       ...
# 3610  27496076  Student Membership   18909  electric
# 3611  27866791  Student Membership   19085  electric
# 3612  29705983             Local31   21789  electric
# 3613  29630616  Student Membership   19619  electric
# 3614  27357116  Student Membership   22196  electric
#
#                     start_time  start_station_id  \
# 0    2016-06-07 01:49:45+00:00              2568
# 1    2016-07-09 18:08:46+00:00              2562
# 2    2016-07-09 18:09:51+00:00              2562
# 3    2016-08-08 02:13:02+00:00              2561
# 4    2020-02-23 14:21:47+00:00              2540
# ...                        ...               ...
# 3610 2022-08-17 14:44:33+00:00              7188
# 3611 2022-09-17 12:56:13+00:00              7188
# 3612 2023-05-24 10:40:21+00:00              7189
# 3613 2023-05-15 13:11:21+00:00              7189
# 3614 2022-08-01 14:09:43+00:00              7189
#
#                                      start_station_name end_station_id  \
# 0                        East 11th St. at Victory Grill           2568
# 1                              San Jacinto & 8th Street           2562
# 2                              San Jacinto & 8th Street           2562
# 3     State Capitol Visitors Garage @ San Jacinto & ...           2561
# 4                                        17th/Guadalupe           2540
# ...                                                 ...            ...
# 3610                                         22nd/Pearl           7189
# 3611                                         22nd/Pearl           7189
# 3612                                    28th/Rio Grande           7189
# 3613                                    28th/Rio Grande           7189
# 3614                                           28th/Rio           7189
#
#                                        end_station_name  duration_minutes
# 0                        East 11th St. at Victory Grill              1405
# 1                              San Jacinto & 8th Street              1087
# 2                              San Jacinto & 8th Street              1150
# 3     State Capitol Visitors Garage @ San Jacinto & ...              1311
# 4                                        17th/Guadalupe              1186
# ...                                                 ...               ...
# 3610                                           28th/Rio              1084
# 3611                                           28th/Rio              1198
# 3612                     23rd/San Jacinto @ DKR Stadium              1451
# 3613                                    28th/Rio Grande              1196
# 3614                                           28th/Rio              1138
#
# [3615 rows x 10 columns]

# %% [markdown]
# # NO 4
# Filter trips where the trip_id is "Walk Up" and the end_station_name  is "Stolen".

# %%
# put your query here
query = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE subscriber_type = 'Walk Up' AND end_station_name = 'Stolen'
"""
# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#     trip_id subscriber_type bike_id bike_type                start_time  \
# 0  13555129         Walk Up     578   classic 2017-01-27 01:35:26+00:00
# 1  13564817         Walk Up     393   classic 2017-01-28 04:57:28+00:00
# 2  11712091         Walk Up     327   classic 2016-09-02 06:37:15+00:00
# 3  11714202         Walk Up     122   classic 2016-09-02 09:00:56+00:00
# 4  13857913         Walk Up     135   classic 2017-02-26 14:32:45+00:00
# 5  16898448         Walk Up    1857   classic 2018-03-18 22:51:20+00:00
# 6  16863172         Walk Up    1795   classic 2018-03-14 21:23:26+00:00
# 7  17151360         Walk Up    1899   classic 2018-04-21 15:29:10+00:00
#
#    start_station_id                                 start_station_name  \
# 0              2498            Convention Center / 4th St. @ MetroRail
# 1              2561  State Capitol Visitors Garage @ San Jacinto & ...
# 2              2565                               Trinity & 6th Street
# 3              2565                               Trinity & 6th Street
# 4              2566                      Pfluger Bridge @ W 2nd Street
# 5              2501                                        5th & Bowie
# 6              2542                                     Plaza Saltillo
# 7              2563                             Davis at Rainey Street
#
#   end_station_id end_station_name  duration_minutes
# 0           None           Stolen              5189
# 1           None           Stolen              4833
# 2           None           Stolen              6118
# 3           None           Stolen              5974
# 4           None           Stolen              1404
# 5           None           Stolen              3806
# 6           None           Stolen              2529
# 7           None           Stolen              4302
